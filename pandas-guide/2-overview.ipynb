# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
casts = pd.read_csv('~/Desktop/python-codes/data/cast.csv')

# %%
casts.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
titles = pd.read_csv('~/Desktop/python-codes/data/titles.csv')

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
pd.set_option('max_columns', 10, 'max_rows', 10)

# %%
casts
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
len(titles)
# Out:
# 50000

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 2 columns):
# title    50000 non-null object
# year     50000 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 781.3+ KB

# %%
titles.shape
# Out:
# (50000, 2)

# %%
# select row from df
titles.iloc[1,:]
# Out:
# title    The Thousand Plane Raid
# year                        1969
# Name: 1, dtype: object

# %%
titles.title
# Out:
# 0                 The Rising Son
# 1        The Thousand Plane Raid
# 2               Crucea de piatra
# 3                        Country
# 4                     Gaiking II
#                   ...
# 49995                      Rebel
# 49996                    Suzanne
# 49997                      Bomba
# 49998       Aao Jao Ghar Tumhara
# 49999                 Mrs. Munck
# Name: title, Length: 50000, dtype: object

# %%
# filter - movies after 1985
after85 = titles[titles.year > 1985]
after85.head()
# Out:
#               title  year
# 0    The Rising Son  1990
# 2  Crucea de piatra  1993
# 3           Country  2000
# 4        Gaiking II  2011
# 5       Medusa (IV)  2015

# %%
# display movies between 1990 and 1999
titles[(titles.year > 1990) & (titles.year < 1999)]
# Out:
#                              title  year
# 2                 Crucea de piatra  1993
# 12        Poka Makorer Ghar Bosoti  1996
# 24            Conflict of Interest  1993
# 32                     Der Brocken  1992
# 35                       The Court  1998
# ...                            ...   ...
# 49969           Chi mei wang liang  1998
# 49979  Gagay: Prinsesa ng brownout  1993
# 49987                I Won't Dance  1992
# 49996                      Suzanne  1996
# 49999                   Mrs. Munck  1995
#
# [3730 rows x 2 columns]

# %%
mac_movies = titles[titles.title == 'Macbeth']

# %%
mac_movies.sort_index()
# Out:
#          title  year
# 4226   Macbeth  1913
# 9322   Macbeth  2006
# 11722  Macbeth  2013
# 17166  Macbeth  1997
# 25847  Macbeth  1998

# %%
# sort by year
mac_movies.sort_values(['year'])
# Out:
#          title  year
# 4226   Macbeth  1913
# 17166  Macbeth  1997
# 25847  Macbeth  1998
# 9322   Macbeth  2006
# 11722  Macbeth  2013

# %%
# descening sort
mac_movies.sort_values(['year'], ascending = [False])
# Out:
#          title  year
# 11722  Macbeth  2013
# 9322   Macbeth  2006
# 25847  Macbeth  1998
# 17166  Macbeth  1997
# 4226   Macbeth  1913

# %%
# find null in 'n' column of casts
casts['n'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: n, dtype: bool

# %%
casts['n'].notnull().head()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: n, dtype: bool

# %%
casts[casts.n.isnull()].head()
# Out:
#                     title  year          name   type                character  \
# 3    Secret in Their Eyes  2015       $hutter  actor          2002 Dodger Fan
# 4              Steve Jobs  2015       $hutter  actor  1988 Opera House Patron
# 5  Straight Outta Compton  2015       $hutter  actor              Club Patron
# 6  Straight Outta Compton  2015       $hutter  actor                  Dopeman
# 7          For Thy Love 2  2009  Bee Moe $lim  actor                   Thug 1
#
#     n
# 3 NaN
# 4 NaN
# 5 NaN
# 6 NaN
# 7 NaN

# %%
# fill na with 'NA'
casts.n.fillna('NA', inplace = True)

# %%
casts[casts.n == 'NA'].head()
# Out:
#                     title  year          name   type                character  \
# 3    Secret in Their Eyes  2015       $hutter  actor          2002 Dodger Fan
# 4              Steve Jobs  2015       $hutter  actor  1988 Opera House Patron
# 5  Straight Outta Compton  2015       $hutter  actor              Club Patron
# 6  Straight Outta Compton  2015       $hutter  actor                  Dopeman
# 7          For Thy Love 2  2009  Bee Moe $lim  actor                   Thug 1
#
#     n
# 3  NA
# 4  NA
# 5  NA
# 6  NA
# 7  NA

# %%
titles[titles['title'] == 'Maa']
# Out:
#       title  year
# 38880   Maa  1968

# %%
titles[titles['title'].str.startswith('Maa')]
# Out:
#                      title  year
# 19        Maa Durga Shakti  1999
# 334             Maarek hob  2004
# 3046         Maa Aur Mamta  1970
# 6304      Maampazhakkaalam  2004
# 7470     Maa Vaibhav Laxmi  1989
# ...                    ...   ...
# 42463        Maa Dasha Maa  1987
# 43448           Maa Balaji  1999
# 45292        Maa Da Laadla  1969
# 48758  Maa Inti Adapaduchu  1996
# 48865            Maa Kasam  1999
#
# [28 rows x 2 columns]

# %%
titles.year.value_counts().head()
# Out:
# 2016    2363
# 2017    2138
# 2015    1849
# 2014    1701
# 2013    1609
# Name: year, dtype: int64

# %%
p = titles.year.value_counts()

# %%
p.plot()
plt.show()

# %%
p = p.sort_index()

# %%
p.plot()
plt.show()

# %%
titles.groupby(['year']).size()
# Out:
# year
# 1900     2
# 1905     1
# 1906     1
# 1909     3
# 1910     5
#         ..
# 2020    37
# 2021     8
# 2022     5
# 2023     1
# 2024     1
# Length: 119, dtype: int64

# %%
titles.groupby(['year']).count()
# Out:
#       title
# year
# 1900      2
# 1905      1
# 1906      1
# 1909      3
# 1910      5
# ...     ...
# 2020     37
# 2021      8
# 2022      5
# 2023      1
# 2024      1
#
# [119 rows x 1 columns]

# %%
casts[casts['name'] == 'Aaron Abrams'].groupby(['year', 'title']).size()
# Out:
# year  title
# 2003  The In-Laws                             1
#       The Visual Bible: The Gospel of John    1
# 2004  Resident Evil: Apocalypse               1
#       Siblings                                1
# 2005  Cinderella Man                          1
#                                              ..
# 2015  Closet Monster                          1
#       Regression                              1
# 2017  #FromJennifer                           1
#       The Go-Getters                          1
# 2018  Code 8                                  1
# Length: 22, dtype: int64

# %%
c = casts[casts['name'] == 'Aaron Abrams']

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 5765 to 5787
# Data columns (total 6 columns):
# title        23 non-null object
# year         23 non-null int64
# name         23 non-null object
# type         23 non-null object
# character    23 non-null object
# n            23 non-null object
# dtypes: int64(1), object(5)
# memory usage: 1.9+ KB

# %%
casts.groupby(['year']).count()['n']
# Out:
# year
# 1912       3
# 1913      10
# 1914      61
# 1915      82
# 1916     116
#         ...
# 2017    2159
# 2018     158
# 2019      16
# 2020       4
# 2023       3
# Name: n, Length: 110, dtype: int64

# %%
casts[casts.n == 'NA'] = np.nan

# %%
casts['n'] = pd.to_numeric(casts['n'], errors = 'coerce')

# %%
c.groupby(['year']).n.mean()
# Out:
# year
# 2003.0    17.0
# 2004.0    14.5
# 2005.0    37.5
# 2007.0    16.5
# 2008.0    44.0
# 2009.0     5.0
# 2011.0    13.8
# 2013.0     3.0
# 2015.0     6.5
# 2017.0     1.0
# Name: n, dtype: float64

# %%
c.groupby(['year']).n.max()
# Out:
# year
# 2003.0    17.0
# 2004.0    20.0
# 2005.0    67.0
# 2007.0    32.0
# 2008.0    44.0
# 2009.0     8.0
# 2011.0    23.0
# 2013.0     3.0
# 2015.0    12.0
# 2017.0     1.0
# Name: n, dtype: float64

# %%
casts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75001 entries, 0 to 75000
# Data columns (total 6 columns):
# title        46035 non-null object
# year         46035 non-null float64
# name         46035 non-null object
# type         46035 non-null object
# character    46035 non-null object
# n            46035 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 3.4+ MB

# %%
casts['decade'] = casts['year'] // 10*10

# %%
casts[casts['name'] == 'Aaron Abrams'].groupby(['decade']).n.size()
# Out:
# decade
# 2000.0    10
# 2010.0     9
# Name: n, dtype: int64

# %%
# unstack
df_decade = casts.groupby(['type', 'decade']).size()

# %%
df_decade.unstack().plot(kind = 'bar')

# %%
df_decade.unstack(0).plot(kind = 'bar')

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
c_amelia = casts[casts['title'] == 'Amelia']

# %%
c_amelia
# Out:
#         title    year            name   type    character     n  decade
# 5767   Amelia  2009.0    Aaron Abrams  actor  Slim Gordon   8.0  2000.0
# 23319  Amelia  2009.0  Jeremy Akerman  actor      Sheriff  19.0  2000.0

# %%
release = pd.read_csv('~/Desktop/python-codes/data/release_dates.csv')

# %%
release.head()
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                 #Beings  2015      Romania  2015-01-29
# 2               #Declimax  2018  Netherlands  2018-01-21
# 3  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 4                 #Horror  2015          USA  2015-11-20

# %%
release[release['title'] == 'Amelia']
# Out:
#         title  year      country        date
# 20543  Amelia  1966       Mexico  1966-03-10
# 20544  Amelia  2009       Canada  2009-10-23
# 20545  Amelia  2009          USA  2009-10-23
# 20546  Amelia  2009    Australia  2009-11-12
# 20547  Amelia  2009    Singapore  2009-11-12
# ...       ...   ...          ...         ...
# 20563  Amelia  2009  Netherlands  2010-03-25
# 20564  Amelia  2009       Brazil  2010-03-26
# 20565  Amelia  2009       France  2010-04-14
# 20566  Amelia  2009      Germany  2010-06-17
# 20567  Amelia  2009        Japan  2010-11-27
#
# [25 rows x 4 columns]

# %%
c_amelia.merge(release)
# Out:
#      title    year            name   type    character     n  decade  \
# 0   Amelia  2009.0    Aaron Abrams  actor  Slim Gordon   8.0  2000.0
# 1   Amelia  2009.0    Aaron Abrams  actor  Slim Gordon   8.0  2000.0
# 2   Amelia  2009.0    Aaron Abrams  actor  Slim Gordon   8.0  2000.0
# 3   Amelia  2009.0    Aaron Abrams  actor  Slim Gordon   8.0  2000.0
# 4   Amelia  2009.0    Aaron Abrams  actor  Slim Gordon   8.0  2000.0
# ..     ...     ...             ...    ...          ...   ...     ...
# 43  Amelia  2009.0  Jeremy Akerman  actor      Sheriff  19.0  2000.0
# 44  Amelia  2009.0  Jeremy Akerman  actor      Sheriff  19.0  2000.0
# 45  Amelia  2009.0  Jeremy Akerman  actor      Sheriff  19.0  2000.0
# 46  Amelia  2009.0  Jeremy Akerman  actor      Sheriff  19.0  2000.0
# 47  Amelia  2009.0  Jeremy Akerman  actor      Sheriff  19.0  2000.0
#
#         country        date
# 0        Canada  2009-10-23
# 1           USA  2009-10-23
# 2     Australia  2009-11-12
# ...

# %%
casts.head()
# Out:
#                  title    year      name   type        character     n  decade
# 0       Closet Monster  2015.0  Buffy #1  actor          Buffy 4  31.0  2010.0
# 1      Suuri illusioni  1985.0    Homo $  actor           Guests  22.0  1980.0
# 2  Battle of the Sexes  2017.0   $hutter  actor  Bobby Riggs Fan  10.0  2010.0
# 3                  NaN     NaN       NaN    NaN              NaN   NaN     NaN
# 4                  NaN     NaN       NaN    NaN              NaN   NaN     NaN

# %%
# %time
casts[casts['title'] == 'Macbeth']
# Out:
# CPU times: user 4 µs, sys: 1 µs, total: 5 µs
# Wall time: 10 µs
#          title    year                 name     type        character     n  \
# 22302  Macbeth  1916.0  Spottiswoode Aitken    actor           Duncan   4.0
# 38090  Macbeth  1948.0       William Alland    actor  Second Murderer  18.0
# 40639  Macbeth  1997.0         Stevie Allen    actor         Murderer  21.0
# 63776  Macbeth  1916.0           Mary Alden  actress     Lady Macduff   6.0
#
#        decade
# 22302  1910.0
# 38090  1940.0
# 40639  1990.0
# 63776  1910.0

# %%
# %%timeit
casts[casts['title'] == 'Macbeth']
# Out:
# 4.61 ms ± 391 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
casts.set_index(['title'], inplace = True)

# %%
# %time
casts.loc['Macbeth']
# Out:
# CPU times: user 4 µs, sys: 1e+03 ns, total: 5 µs
# Wall time: 11.2 µs
#            year                 name     type        character     n  decade
# title
# Macbeth  1916.0  Spottiswoode Aitken    actor           Duncan   4.0  1910.0
# Macbeth  1948.0       William Alland    actor  Second Murderer  18.0  1940.0
# Macbeth  1997.0         Stevie Allen    actor         Murderer  21.0  1990.0
# Macbeth  1916.0           Mary Alden  actress     Lady Macduff   6.0  1910.0

# %%
casts.sort_index(inplace = True)

# %%
casts
# Out:
#                     year           name     type           character     n  \
# title
# #1 Serial Killer  2013.0  Michael Alton    actor   Detective Roberts  17.0
# #Horror           2015.0     Emma Adler  actress             Georgie   1.0
# #Lucky Number     2015.0   Grace Abbott  actress  Internet Porn Star  31.0
# #Stuck            2014.0   Logan Agayan    actor                Baby  18.0
# #Y                2014.0  Sophie Albert  actress                 Lia   4.0
# ...                  ...            ...      ...                 ...   ...
# NaN                  NaN            NaN      NaN                 NaN   NaN
# NaN                  NaN            NaN      NaN                 NaN   NaN
# NaN                  NaN            NaN      NaN                 NaN   NaN
# NaN                  NaN            NaN      NaN                 NaN   NaN
# NaN                  NaN            NaN      NaN                 NaN   NaN
#
#                   decade
# title
# #1 Serial Killer  2010.0
# ...

# %%
casts.set_index(['year', 'n']).sort_index()
# Out:
#                         name     type             character  decade
# year   n
# 1912.0 6.0  James D. Ainsley    actor      John the Baptist  1910.0
#        6.0        Rina Albry  actress        Una cortigiana  1910.0
# 1913.0 1.0      Carl Alstrup    actor  Prince Karl Heinrich  1910.0
#        1.0      Carl Alstrup    actor    Journalist Herbert  1910.0
#        2.0    Ren? Alexandre    actor  Le peintre Alexandre  1910.0
# ...                      ...      ...                   ...     ...
# NaN    NaN               NaN      NaN                   NaN     NaN
#        NaN               NaN      NaN                   NaN     NaN
#        NaN               NaN      NaN                   NaN     NaN
#        NaN               NaN      NaN                   NaN     NaN
#        NaN               NaN      NaN                   NaN     NaN
#
# [75001 rows x 4 columns]

# %%
casts.reset_index()
# Out:
#                   title    year           name     type           character  \
# 0      #1 Serial Killer  2013.0  Michael Alton    actor   Detective Roberts
# 1               #Horror  2015.0     Emma Adler  actress             Georgie
# 2         #Lucky Number  2015.0   Grace Abbott  actress  Internet Porn Star
# 3                #Stuck  2014.0   Logan Agayan    actor                Baby
# 4                    #Y  2014.0  Sophie Albert  actress                 Lia
# ...                 ...     ...            ...      ...                 ...
# 74996               NaN     NaN            NaN      NaN                 NaN
# 74997               NaN     NaN            NaN      NaN                 NaN
# 74998               NaN     NaN            NaN      NaN                 NaN
# 74999               NaN     NaN            NaN      NaN                 NaN
# 75000               NaN     NaN            NaN      NaN                 NaN
#
#           n  decade
# 0      17.0  2010.0
# ...
